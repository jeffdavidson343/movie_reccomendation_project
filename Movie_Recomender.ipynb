# %%
# import dependencies
import pandas as pd
import numpy as np
from numpy import array
from numpy import asarray
from numpy import zeros
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import os.path
import re
import pickle
import requests
import math


import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split

# %%
movies = pd.read_csv("movies.csv")
ratings = pd.read_csv("ratings.csv")
tags = pd.read_csv("tags.csv")
links = pd.read_csv("links.csv")
genome_tags = pd.read_csv("genome_tags.csv")
genome_scores = pd.read_csv("genome_scores.csv")

# %%
# %%time
user_ids = ratings.userId.unique().tolist()
user2idx = {userId: idx for (idx, userId) in enumerate(user_ids)}
idx2user = {idx: userId for (idx, userId) in enumerate(user_ids)}
ratings.userId = ratings.userId.map(user2idx)

movie_ids = ratings.movieId.unique().tolist()
movie2idx = {movieId: idx for (idx, movieId) in enumerate(movie_ids)}
idx2movie = {idx: movieId for (idx, movieId) in enumerate(movie_ids)}
ratings.movieId = ratings.movieId.map(movie2idx)

# map rest
tags.movieId = tags.movieId.map(movie2idx)
movies.movieId = movies.movieId.map(movie2idx)
links.movieId = links.movieId.map(movie2idx)
# Out:
# CPU times: user 402 ms, sys: 252 ms, total: 655 ms
# Wall time: 723 ms

# %%
num_users = int(ratings.userId.nunique())
num_movies = int(ratings.movieId.nunique())
ratings["rating"] = ratings["rating"].values.astype(np.float32)
# min and max ratings will be used to normalize the ratings later
min_rating = min(ratings["rating"])
max_rating = max(ratings["rating"])

print(
    "Number of users: {}, Number of Movies: {}, Min rating: {}, Max rating: {}".format(
        num_users, num_movies, min_rating, max_rating
    )
)
# Out:
# Number of users: 162541, Number of Movies: 59047, Min rating: 0.5, Max rating: 5.0

# %%
# drop some columns we do not care about
ratings = ratings.drop("timestamp", axis=1)
tags = tags.drop("timestamp", axis=1)

# %%
# drop duplicates for ratings for content 
ratings_content = ratings.drop_duplicates("movieId")

# %%
# we need take make sure that we have equal movies and ratings.
movies.isnull().sum()
# Out:
# movieId    3376
# title         0
# genres        0
# dtype: int64

# %%
movies[~movies.movieId.isin(ratings_content.movieId)]
# Out:
#        movieId                                            title  \
# 8371       NaN                           Break of Hearts (1935)
# 8763       NaN                          Baby Blue Marine (1976)
# 11556      NaN  Thousand and One Nights, A (1001 Nights) (1945)
# 11997      NaN                           Suicide Killers (2006)
# 12173      NaN           Alex in Wonder (Sex and a Girl) (2001)
# ...        ...                                              ...
# 62238      NaN                             Eternal Blood (2002)
# 62239      NaN                              Big Business (1929)
# 62240      NaN                     The Student of Prague (1926)
# 62298      NaN                          The Coldest Game (2019)
# 62342      NaN                                     Spell (2018)
#
#                        genres
# 8371            Drama|Romance
# 8763                    Drama
# 11556               Adventure
# 11997             Documentary
# 12173            Comedy|Drama
# ...                       ...
# 62238  Action|Horror|Thriller
# 62239                  Comedy
# 62240                  Horror
# 62298      (no genres listed)
# 62342   Comedy|Drama|Thriller
#
# [3376 rows x 3 columns]

# %%
movies = movies[movies['movieId'].notna()]

# %%
movies.isnull().sum()
# Out:
# movieId    0
# title      0
# genres     0
# dtype: int64

# %%
# basic stats
print("{} unique movies in ratings_content".format(len(ratings_content.movieId.unique())))
print("{} unique movies in tags.csv".format(len(tags.movieId.unique())))
print("{} unique movies in movies.csv".format(len(movies.movieId.unique())))
# Out:
# 59047 unique movies in ratings_content
# 41876 unique movies in tags.csv
# 59047 unique movies in movies.csv

# %%
# do we have tags with movies that do NOT have a ratings?
len(tags[~tags["movieId"].isin(ratings_content.movieId)]["movieId"].unique())
# Out:
# 1

# %%
# movies that are not in ratings, should be removed (using right join)
tags_content = pd.merge(tags, ratings_content, on="movieId", how="right")

# %%
tags_content[tags_content.movieId == 0]
# Out:
#       userId_x  movieId                          tag  userId_y  rating
# 0        264.0      0.0                     assassin         0     5.0
# 1        264.0      0.0                 Black comedy         0     5.0
# 2        264.0      0.0                    cult film         0     5.0
# 3        264.0      0.0                  dark comedy         0     5.0
# 4        264.0      0.0            Quentin Tarantino         0     5.0
# ...        ...      ...                          ...       ...     ...
# 4762  162400.0      0.0  Oscar Nominee: Best Picture         0     5.0
# 4763  162400.0      0.0            Quentin Tarantino         0     5.0
# 4764  162400.0      0.0                       satire         0     5.0
# 4765  162400.0      0.0                Steve Buscemi         0     5.0
# 4766  162400.0      0.0                     suspense         0     5.0
#
# [4767 rows x 5 columns]

# %%
tags_content.head()
# Out:
#    userId_x  movieId                tag  userId_y  rating
# 0     264.0      0.0           assassin         0     5.0
# 1     264.0      0.0       Black comedy         0     5.0
# 2     264.0      0.0          cult film         0     5.0
# 3     264.0      0.0        dark comedy         0     5.0
# 4     264.0      0.0  Quentin Tarantino         0     5.0

# %%
len(tags[~tags["movieId"].isin(ratings_content.movieId)]["movieId"].unique())
# Out:
# 1

# %%
# after some clean
print("{} unique movies in ratings_content".format(len(ratings_content.movieId.unique())))
print("{} unique movies in tags_content".format(len(tags_content.movieId.unique())))
print("{} unique movies in movies.csv".format(len(movies.movieId.unique())))
# Out:
# 59047 unique movies in ratings_content
# 59047 unique movies in tags_content
# 59047 unique movies in movies.csv

# %%
# handle genres (remove all non alphabet characters)
movies['genres'] = movies['genres'].str.replace(pat="|", repl=" ")
movies['genres'] = movies['genres'].str.replace(pat="-", repl="")
movies['genres'] = movies['genres'].str.replace(pat="(no genres listed)", repl="")
movies['genres'] = movies['genres'].str.replace(pat="(", repl="")
movies['genres'] = movies['genres'].str.replace(pat=")", repl="")
movies.head()
# Out:
# /var/folders/wh/dcrmmvwj20v17sfy6sn_5xyr0000gn/T/ipykernel_87242/3016070273.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   movies['genres'] = movies['genres'].str.replace(pat="|", repl=" ")
# /var/folders/wh/dcrmmvwj20v17sfy6sn_5xyr0000gn/T/ipykernel_87242/3016070273.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   movies['genres'] = movies['genres'].str.replace(pat="(no genres listed)", repl="")
# /var/folders/wh/dcrmmvwj20v17sfy6sn_5xyr0000gn/T/ipykernel_87242/3016070273.py:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   movies['genres'] = movies['genres'].str.replace(pat="(", repl="")
# /var/folders/wh/dcrmmvwj20v17sfy6sn_5xyr0000gn/T/ipykernel_87242/3016070273.py:6: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   movies['genres'] = movies['genres'].str.replace(pat=")", repl="")
#    movieId                               title  \
# 0     70.0                    Toy Story (1995)
# 1   1103.0                      Jumanji (1995)
# 2   1017.0             Grumpier Old Men (1995)
# 3   4270.0            Waiting to Exhale (1995)
# 4   1858.0  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure Animation Children Comedy Fantasy
# 1                   Adventure Children Fantasy
# 2                               Comedy Romance
# 3                         Comedy Drama Romance
# 4                                       Comedy

# %%
# merge movies with ratings and map idx
movies_content = pd.merge(movies, ratings_content, on="movieId", how="inner")

# %%
movies.query("title == 'Batman Begins (2005)'")
# Out:
#        movieId                 title             genres
# 10002    245.0  Batman Begins (2005)  Action Crime IMAX

# %%
# there is some nans in tags
tags_content.isnull().sum().sort_values(ascending = False)
# Out:
# tag         17188
# userId_x    17172
# movieId         0
# userId_y        0
# rating          0
# dtype: int64

# %%
# fill some nans 
tags_content.fillna("", inplace=True)

# %%
tags_content.isnull().sum().sort_values(ascending = False)
# Out:
# userId_x    0
# movieId     0
# tag         0
# userId_y    0
# rating      0
# dtype: int64

# %%
tags_content = pd.DataFrame(tags_content.groupby('movieId')['tag'].apply(lambda x: "%s" % ' '.join(x)))
tags_content.reset_index(inplace=True)

# %%
tags_content.head()
# Out:
#    movieId                                                tag
# 0      0.0  assassin Black comedy cult film dark comedy Qu...
# 1      1.0  atmospheric enigmatic gentle lyrical meditativ...
# 2      2.0  atmospheric CRISIS OF FAITH DEATH OF A CHILD D...
# 3      3.0  biting cerebral cynical harsh irreverent madca...
# 4      4.0  Dance 50s imdb top 250 musical romance happy m...

# %%
movies_content.head()
# Out:
#    movieId                               title  \
# 0     70.0                    Toy Story (1995)
# 1   1103.0                      Jumanji (1995)
# 2   1017.0             Grumpier Old Men (1995)
# 3   4270.0            Waiting to Exhale (1995)
# 4   1858.0  Father of the Bride Part II (1995)
#
#                                         genres  userId  rating
# 0  Adventure Animation Children Comedy Fantasy       1     3.5
# 1                   Adventure Children Fantasy       8     5.0
# 2                               Comedy Romance       7     4.0
# 3                         Comedy Drama Romance     140     3.0
# 4                                       Comedy      17     4.0

# %%
# group tags by movie id to create corpus
content_data = pd.merge(movies_content, tags_content, on="movieId", how="right")
content_data["corpus"] = content_data[["genres", "tag"]].apply(lambda x: " ".join(x), axis=1)

# %%
movies_content[movies_content.movieId == 245]
# Out:
#        movieId                 title             genres  userId  rating
# 10000    245.0  Batman Begins (2005)  Action Crime IMAX       1     5.0

# %%
content_data[content_data.movieId == 245]
# Out:
#      movieId                 title             genres  userId  rating  \
# 245    245.0  Batman Begins (2005)  Action Crime IMAX       1     5.0
#
#                                                    tag  \
# 245  action batman billionaire Christian Bale comic...
#
#                                                 corpus
# 245  Action Crime IMAX action batman billionaire Ch...

# %%
# drop items we do not need 
content_data = content_data.drop("rating", axis=1)
content_data = content_data.drop("userId", axis=1)

# %%
content_data.head()
# Out:
#    movieId                                             title  \
# 0      0.0                               Pulp Fiction (1994)
# 1      1.0  Three Colors: Red (Trois couleurs: Rouge) (1994)
# 2      2.0  Three Colors: Blue (Trois couleurs: Bleu) (1993)
# 3      3.0                                Underground (1995)
# 4      4.0                        Singin' in the Rain (1952)
#
#                         genres  \
# 0  Comedy Crime Drama Thriller
# 1                        Drama
# 2                        Drama
# 3             Comedy Drama War
# 4       Comedy Musical Romance
#
#                                                  tag  \
# 0  assassin Black comedy cult film dark comedy Qu...
# 1  atmospheric enigmatic gentle lyrical meditativ...
# 2  atmospheric CRISIS OF FAITH DEATH OF A CHILD D...
# 3  biting cerebral cynical harsh irreverent madca...
# 4  Dance 50s imdb top 250 musical romance happy m...
#
#                                               corpus
# 0  Comedy Crime Drama Thriller assassin Black com...
# 1  Drama atmospheric enigmatic gentle lyrical med...
# 2  Drama atmospheric CRISIS OF FAITH DEATH OF A C...
# 3  Comedy Drama War biting cerebral cynical harsh...
# 4  Comedy Musical Romance Dance 50s imdb top 250 ...

# %%
# find ratings count and mean
movie_summary = pd.DataFrame(ratings.groupby('movieId')['rating'].mean())
movie_summary['ratings_count'] = ratings.groupby('movieId')['rating'].count()
movie_summary.head()
# Out:
#            rating  ratings_count
# movieId
# 0        4.188912          79672
# 1        4.072967           7058
# 2        3.981409           6616
# 3        3.946021           1269
# 4        4.050987          10895

# %%
# merge with content data
content_data = pd.merge(content_data, movie_summary, on="movieId", how="left")
content_data.head()
# Out:
#    movieId                                             title  \
# 0      0.0                               Pulp Fiction (1994)
# 1      1.0  Three Colors: Red (Trois couleurs: Rouge) (1994)
# 2      2.0  Three Colors: Blue (Trois couleurs: Bleu) (1993)
# 3      3.0                                Underground (1995)
# 4      4.0                        Singin' in the Rain (1952)
#
#                         genres  \
# 0  Comedy Crime Drama Thriller
# 1                        Drama
# 2                        Drama
# 3             Comedy Drama War
# 4       Comedy Musical Romance
#
#                                                  tag  \
# 0  assassin Black comedy cult film dark comedy Qu...
# 1  atmospheric enigmatic gentle lyrical meditativ...
# 2  atmospheric CRISIS OF FAITH DEATH OF A CHILD D...
# 3  biting cerebral cynical harsh irreverent madca...
# 4  Dance 50s imdb top 250 musical romance happy m...
#
#                                               corpus    rating  ratings_count
# 0  Comedy Crime Drama Thriller assassin Black com...  4.188912          79672
# 1  Drama atmospheric enigmatic gentle lyrical med...  4.072967           7058
# 2  Drama atmospheric CRISIS OF FAITH DEATH OF A C...  3.981409           6616
# 3  Comedy Drama War biting cerebral cynical harsh...  3.946021           1269
# 4  Comedy Musical Romance Dance 50s imdb top 250 ...  4.050987          10895

# %%
content_data.shape
# Out:
# (59047, 7)

# %%
C = content_data["rating"].mean()
print(C)
m = content_data["ratings_count"].quantile(0.90)
print(m)
# Out:
# 3.071374
# 413.0

# %%
# weighted ratings based on IMDB
def weighted_rating(x):
    v = x['ratings_count']
    R = x['rating']
    return (v / (v + m) * R) + (m / (m + v) * C)

# %%
content_data["weighted_rating"] = content_data.apply(weighted_rating, axis=1)

# %%
content_data = pd.merge(content_data, links, on="movieId", how="left")

# %%
content_data.sort_values("weighted_rating", ascending=False).head(20)
# Out:
#       movieId                                              title  \
# 79       79.0                   Shawshank Redemption, The (1994)
# 96       96.0                              Godfather, The (1972)
# 252     252.0                         Usual Suspects, The (1995)
# 276     276.0                     Godfather: Part II, The (1974)
# 89       89.0                            Schindler's List (1993)
# 297     297.0                                  Fight Club (1999)
# 288     288.0        Seven Samurai (Shichinin no samurai) (1954)
# 1063   1063.0                                 Rear Window (1954)
# 999     999.0                                12 Angry Men (1957)
# 1844   1844.0             One Flew Over the Cuckoo's Nest (1975)
# 1057   1057.0  Dr. Strangelove or: How I Learned to Stop Worr...
# 907     907.0                                Planet Earth (2006)
# 860     860.0  Spirited Away (Sen to Chihiro no kamikakushi) ...
# 265     265.0                                  Casablanca (1942)
# 0         0.0                                Pulp Fiction (1994)
# 1305   1305.0                          North by Northwest (1959)
# 274     274.0                                  Goodfellas (1990)
# 37       37.0                City of God (Cidade de Deus) (2002)
# 578     578.0                            Dark Knight, The (2008)
# 1663   1663.0  Lives of Others, The (Das leben der Anderen) (...
#
#                                          genres  \
# 79                                  Crime Drama
# 96                                  Crime Drama
# 252                      Crime Mystery Thriller
# 276                                 Crime Drama
# 89                                    Drama War
# 297                 Action Crime Drama Thriller
# 288                      Action Adventure Drama
# 1063                           Mystery Thriller
# 999                                       Drama
# 1844                                      Drama
# 1057                                 Comedy War
# 907                                 Documentary
# 860                 Adventure Animation Fantasy
# 265                               Drama Romance
# 0                   Comedy Crime Drama Thriller
# 1305  Action Adventure Mystery Romance Thriller
# 274                                 Crime Drama
# 37        Action Adventure Crime Drama Thriller
# 578                     Action Crime Drama IMAX
# 1663                     Drama Romance Thriller
#
#                                                     tag  \
# 79    bad ending stephan king freedom hope inspirati...
# 96    italian mafia italy Mafia Marlon Brando Mafia ...
# 252   imdb top 250 heist suspense thriller twist end...
# 276   imdb top 250 Oscar (Best Picture) 100 Greatest...
# 89    based on a true story true story imdb top 250 ...
# 297   complicated mindfuck violence atmospheric dark...
# 288   Akira Kurosawa atmospheric epic historical lon...
# 1063  50s imdb top 250 Edgar Award (Best Motion Pict...
# 999   classic courtroom courtroom drama group psycho...
# 1844  imdb top 250 Oscar (Best Picture) asylum based...
# 1057  ending kinda ruined it imdb top 250 100 Greate...
# 907   David Attenborough nature amazing photography ...
# 860   imdb top 250 adventure alternate reality amazi...
# 265   imdb top 250 Oscar (Best Picture) atmospheric ...
# 0     assassin Black comedy cult film dark comedy Qu...
# 1305  imdb top 250 Alfred Hitchcock Cary Grant Eva M...
# 274   mafia Martin Scorsese crime dark comedy gangst...
# 37    atmospheric crime disturbing drugs multiple st...
# 578   action Atmospheric Batman Christian Bale comic...
# 1663  imdb top 250 East Germany stasi surveillance B...
#
#                                                  corpus    rating  \
# 79    Crime Drama bad ending stephan king freedom ho...  4.413576
# 96    Crime Drama italian mafia italy Mafia Marlon B...  4.324336
# 252   Crime Mystery Thriller imdb top 250 heist susp...  4.284353
# 276   Crime Drama imdb top 250 Oscar (Best Picture) ...  4.261758
# 89    Drama War based on a true story true story imd...  4.247579
# 297   Action Crime Drama Thriller complicated mindfu...  4.228311
# 288   Action Adventure Drama Akira Kurosawa atmosphe...  4.254769
# 1063  Mystery Thriller 50s imdb top 250 Edgar Award ...  4.237947
# 999   Drama classic courtroom courtroom drama group ...  4.243014
# 1844  Drama imdb top 250 Oscar (Best Picture) asylum...  4.218662
# 1057  Comedy War ending kinda ruined it imdb top 250...  4.215805
# 907   Documentary David Attenborough nature amazing ...  4.464797
# 860   Adventure Animation Fantasy imdb top 250 adven...  4.212267
# 265   Drama Romance imdb top 250 Oscar (Best Picture...  4.206564
# 0     Comedy Crime Drama Thriller assassin Black com...  4.188912
# 1305  Action Adventure Mystery Romance Thriller imdb...  4.196617
# 274   Crime Drama mafia Martin Scorsese crime dark c...  4.180525
# 37    Action Adventure Crime Drama Thriller atmosphe...  4.181587
# 578   Action Crime Drama IMAX action Atmospheric Bat...  4.166538
# 1663  Drama Romance Thriller imdb top 250 East Germa...  4.200392
#
#       ratings_count  weighted_rating  imdbId    tmdbId
# 79            81482         4.406807  111161     278.0
# 96            52498         4.314556   68646     238.0
# 252           55366         4.275372  114814     629.0
# 276           34188         4.247550   71562     240.0
# 89            60411         4.239593  108052     424.0
# 297           58773         4.220237  137523     550.0
# 288           13367         4.219302   47478     346.0
# 1063          20162         4.214531   47396     567.0
# 999           16569         4.214520   50083     389.0
# 1844          36058         4.205670   73486     510.0
# 1057          26714         4.198381   57012     935.0
# 907            1747         4.198369  795176  192040.0
# 860           22719         4.191898  245429     129.0
# 265           26890         4.189392   34583     289.0
# 0             79672         4.183149  110912     680.0
# 1305          16850         4.169697   53125     213.0
# 274           32663         4.166676   99685     769.0
# 37            19894         4.159008  317248     598.0
# 578           41519         4.155752  468569     155.0
# 1663           9177         4.151770  405094     582.0
